# %%
# %pip install curl-cffi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # yFinance
#
# https://github.com/ranaroussi/yfinance

# %%
# Dates and times.

import datetime as dt # For handling dates and times. This is a sandard library in Python.

# Data frames.
import pandas as pd # For data manipulation and analysis. This is not a standard library in Python.

# Yahoo Finance data.
import yfinance as yf # For downloading financial data from Yahoo Finance. This is not a standard library in Python.

# Numerical arrays.
import numpy as np # For numerical operations. This is not a standard library in Python.

# Plotting.
import matplotlib.pyplot as plt

from curl_cffi import requests
session = requests.Session(impersonate="chrome")
ticker = yf.Ticker('...', session=session)

# %%
#pip install --upgrade yfinance --no-cache-dir

# %%
"""
import os
import shutil
from pathlib import Path
import platformdirs  # jeśli nie masz: pip install platformdirs

cache_dir = Path(platformdirs.user_cache_dir()) / "py-yfinance"
print("Cache dir:", cache_dir)

# USUNIĘCIE cache – bezpieczne, zostanie odtworzony przy następnym wywołaniu
shutil.rmtree(cache_dir, ignore_errors=True)
"""
# Out:
# '\nimport os\nimport shutil\nfrom pathlib import Path\nimport platformdirs  # jeśli nie masz: pip install platformdirs\n\ncache_dir = Path(platformdirs.user_cache_dir()) / "py-yfinance"\nprint("Cache dir:", cache_dir)\n\n# USUNIĘCIE cache – bezpieczne, zostanie odtworzony przy następnym wywołaniu\nshutil.rmtree(cache_dir, ignore_errors=True)\n'

# %%
yf.download("AAPL", start="2020-01-01", end="2020-12-31")
# Out:
# /var/folders/q2/x0y2jr6d0zn8h5ft8hmn3_rw0000gn/T/ipykernel_2318/1945424988.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf.download("AAPL", start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.468269   72.528589   71.223267   71.476607  135480400
# 2020-01-03   71.763725   72.523754   71.539337   71.696167  146322800
# 2020-01-06   72.335556   72.374162   70.634539   70.885472  118387200
# 2020-01-07   71.995369   72.600975   71.775804   72.345220  108872000
# 2020-01-08   73.153519   73.455118   71.698604   71.698604  132079200
# ...                ...         ...         ...         ...        ...
# 2020-12-23  127.483299  128.914260  127.308070  128.651439   88223700
# ...

# %%
# Get the data for Microsoft
dat = yf.Ticker("MSFT")

# %%
# Have a look
dat
# Out:
# yfinance.Ticker object <MSFT>

# %%
dat.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
dat.calendar
# Out:
# {'Dividend Date': datetime.date(2025, 12, 11),
#  'Ex-Dividend Date': datetime.date(2025, 11, 20),
#  'Earnings Date': [datetime.date(2026, 1, 28)],
#  'Earnings High': 4.11521,
#  'Earnings Low': 3.56,
#  'Earnings Average': 3.90411,
#  'Revenue High': 81661025500,
#  'Revenue Low': 78581000000,
#  'Revenue Average': 80281911770}

# %%
dat.analyst_price_targets
# Out:
# {'current': 490.0,
#  'high': 730.0,
#  'low': 483.0,
#  'mean': 625.4096,
#  'median': 634.15}

# %%
dat.history(period="1mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-11-03 00:00:00-05:00  518.838923  523.979326  513.628704  516.064148
# 2025-11-04 00:00:00-05:00  510.803995  514.586893  506.891305  513.369202
# 2025-11-05 00:00:00-05:00  512.341069  513.868240  505.633621  506.212555
# 2025-11-06 00:00:00-05:00  504.715363  504.755296  494.883758  496.171356
# 2025-11-07 00:00:00-05:00  496.021638  498.447091  492.328538  495.891876
# 2025-11-10 00:00:00-05:00  499.105861  505.903136  497.868156  505.054718
# 2025-11-11 00:00:00-05:00  503.856949  508.648001  501.411545  507.729706
# 2025-11-12 00:00:00-05:00  508.408446  510.714159  498.187585  510.185150
# 2025-11-13 00:00:00-05:00  509.356667  512.540710  500.353529  502.349792
# 2025-11-14 00:00:00-05:00  497.299241  510.644259  496.510708  509.226898
# 2025-11-17 00:00:00-05:00  507.500160  511.163287  503.966764  506.541931
# 2025-11-18 00:00:00-05:00  494.444589  502.040388  485.870639  492.867554
# ...

# %%
# Multiple tickers
tickers = yf.Tickers("MSFT AAPL GOOG NVDA")

# %%
tickers
# Out:
# yfinance.Tickers object <MSFT,AAPL,GOOG,NVDA>

# %%
tickers.tickers["MSFT"].info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
yf.download("MSFT AAPL GOOG", period="1mo")
# Out:
# /var/folders/q2/x0y2jr6d0zn8h5ft8hmn3_rw0000gn/T/ipykernel_2318/2260873134.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf.download("MSFT AAPL GOOG", period="1mo")
# [*********************100%***********************]  3 of 3 completed
# Price            Close                                High              \
# Ticker            AAPL        GOOG        MSFT        AAPL        GOOG
# Date
# 2025-11-03  268.789429  284.119995  516.064148  270.587704  285.940002
# 2025-11-04  269.778473  278.059998  513.369202  271.227050  281.834015
# 2025-11-05  269.878387  284.750000  506.212555  271.436874  286.700012
# 2025-11-06  269.508728  285.339996  496.171356  273.135217  288.809998
# 2025-11-07  268.209991  279.700012  495.891876  272.026299  284.500000
# 2025-11-10  269.429993  290.589996  505.054718  273.730011  291.459991
# 2025-11-11  275.250000  291.739990  507.729706  275.910004  292.339996
# ...

# %%
# Get historical data for multiple tickers at once.
df = yf.download(['MSFT', 'AAPL','GOOG'], period='1mo')
# Out:
# /var/folders/q2/x0y2jr6d0zn8h5ft8hmn3_rw0000gn/T/ipykernel_2318/3965022185.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(['MSFT', 'AAPL','GOOG'], period='1mo')
# [*********************100%***********************]  3 of 3 completed

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close', 'GOOG'),
#             ( 'Close', 'MSFT'),
#             (  'High', 'AAPL'),
#             (  'High', 'GOOG'),
#             (  'High', 'MSFT'),
#             (   'Low', 'AAPL'),
#             (   'Low', 'GOOG'),
#             (   'Low', 'MSFT'),
#             (  'Open', 'AAPL'),
#             (  'Open', 'GOOG'),
#             (  'Open', 'MSFT'),
#             ('Volume', 'AAPL'),
#             ('Volume', 'GOOG'),
#             ('Volume', 'MSFT')],
#            names=['Price', 'Ticker'])

# %%
df.index
# Out:
# DatetimeIndex(['2025-11-03', '2025-11-04', '2025-11-05', '2025-11-06',
#                '2025-11-07', '2025-11-10', '2025-11-11', '2025-11-12',
#                '2025-11-13', '2025-11-14', '2025-11-17', '2025-11-18',
#                '2025-11-19', '2025-11-20', '2025-11-21', '2025-11-24',
#                '2025-11-25', '2025-11-26', '2025-11-28', '2025-12-01',
#                '2025-12-02'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %% [markdown]
# ## The download() Function

# %%
# Get data
df = yf.download(['MSFT', 'AAPL', 'GOOG', 'NVDA'], period='1mo')

# Show
df
# Out:
# /var/folders/q2/x0y2jr6d0zn8h5ft8hmn3_rw0000gn/T/ipykernel_2318/2307269503.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(['MSFT', 'AAPL', 'GOOG', 'NVDA'], period='1mo')
# [*********************100%***********************]  4 of 4 completed
# Price            Close                                            High  \
# Ticker            AAPL        GOOG        MSFT        NVDA        AAPL
# Date
# 2025-11-03  268.789429  284.119995  516.064148  206.880005  270.587704
# 2025-11-04  269.778473  278.059998  513.369202  198.690002  271.227050
# 2025-11-05  269.878387  284.750000  506.212555  195.210007  271.436874
# 2025-11-06  269.508728  285.339996  496.171356  188.080002  273.135217
# 2025-11-07  268.209991  279.700012  495.891876  188.149994  272.026299
# 2025-11-10  269.429993  290.589996  505.054718  199.050003  273.730011
# 2025-11-11  275.250000  291.739990  507.729706  193.160004  275.910004
# ...

# %%
# Get data
df = yf.download(['MSFT', 'AAPL', 'GOOG', 'NVDA'], period='5d', interval='1h')

# Show
df
# Out:
# /var/folders/q2/x0y2jr6d0zn8h5ft8hmn3_rw0000gn/T/ipykernel_2318/953538531.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(['MSFT', 'AAPL', 'GOOG', 'NVDA'], period='5d', interval='1h')
# [*********************100%***********************]  4 of 4 completed
# Price                           Close                                      \
# Ticker                           AAPL        GOOG        MSFT        NVDA
# Datetime
# 2025-11-25 14:30:00+00:00  278.904999  327.320007  468.380005  171.074997
# 2025-11-25 15:30:00+00:00  277.829987  320.679993  472.149994  174.723801
# 2025-11-25 16:30:00+00:00  279.070099  321.404999  475.989990  175.535004
# 2025-11-25 17:30:00+00:00  278.760010  324.230011  476.744995  176.205002
# 2025-11-25 18:30:00+00:00  278.035004  323.007996  476.380005  174.774994
# 2025-11-25 19:30:00+00:00  277.565002  321.700104  477.088501  176.841705
# ...

# %%
# Show the type of the DataFrame.
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# The index.
df.index
# Out:
# DatetimeIndex(['2025-11-25 14:30:00+00:00', '2025-11-25 15:30:00+00:00',
#                '2025-11-25 16:30:00+00:00', '2025-11-25 17:30:00+00:00',
#                '2025-11-25 18:30:00+00:00', '2025-11-25 19:30:00+00:00',
#                '2025-11-25 20:30:00+00:00', '2025-11-26 14:30:00+00:00',
#                '2025-11-26 15:30:00+00:00', '2025-11-26 16:30:00+00:00',
#                '2025-11-26 17:30:00+00:00', '2025-11-26 18:30:00+00:00',
#                '2025-11-26 19:30:00+00:00', '2025-11-26 20:30:00+00:00',
#                '2025-11-28 14:30:00+00:00', '2025-11-28 15:30:00+00:00',
#                '2025-11-28 16:30:00+00:00', '2025-12-01 14:30:00+00:00',
#                '2025-12-01 15:30:00+00:00', '2025-12-01 16:30:00+00:00',
#                '2025-12-01 17:30:00+00:00', '2025-12-01 18:30:00+00:00',
#                '2025-12-01 19:30:00+00:00', '2025-12-01 20:30:00+00:00',
#                '2025-12-02 14:30:00+00:00', '2025-12-02 15:30:00+00:00',
# ...

# %%
# Print data as CSV.
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html

print(df.to_csv())
# Out:
# Price,Close,Close,Close,Close,High,High,High,High,Low,Low,Low,Low,Open,Open,Open,Open,Volume,Volume,Volume,Volume
# Ticker,AAPL,GOOG,MSFT,NVDA,AAPL,GOOG,MSFT,NVDA,AAPL,GOOG,MSFT,NVDA,AAPL,GOOG,MSFT,NVDA,AAPL,GOOG,MSFT,NVDA
# Datetime,,,,,,,,,,,,,,,,,,,,
# 2025-11-25 14:30:00+00:00,278.9049987792969,327.32000732421875,468.3800048828125,171.0749969482422,280.3800048828125,328.6700134277344,474.5,175.0,275.2699890136719,319.79998779296875,464.8918151855469,169.5500030517578,275.29998779296875,326.875,474.3949890136719,174.91000366210938,9723608,13790107,4558757,79887076
# 2025-11-25 15:30:00+00:00,277.8299865722656,320.67999267578125,472.1499938964844,174.7238006591797,279.6300048828125,328.1000061035156,472.3599853515625,174.8800048828125,277.7799987792969,317.81640625,468.3370056152344,171.0281982421875,278.8900146484375,327.2900085449219,468.3800048828125,171.07000732421875,2840433,6785175,1948411,33770896
# ...

# %%
# Save data as CSV.
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html

df.to_csv('../data/data.csv')

# %% [markdown]
# ## Dates and Times
#
# https://docs.python.org/3.12/library/datetime.html

# %%
dt
# Out:
# <module 'datetime' from '/opt/anaconda3/lib/python3.12/datetime.py'>

# %%
dt.datetime.now() # Current date and time.
# Out:
# datetime.datetime(2025, 12, 3, 0, 0, 18, 493468)

# %%
# Current date and time.
now = dt.datetime.now()

# Show
now
# Out:
# datetime.datetime(2025, 12, 3, 0, 0, 18, 514316)

# %%
# Format date and time.
now.strftime("%Y-%m-%d %H:%M:%S") # Format as "YYYY-MM-DD HH:MM:SS".
# Out:
# '2025-12-03 00:00:18'

# %%
# Format date and time.
now.strftime("%Y%m%d-%H%M%S") # Format as "YYYYMMDD-HHMMSS".
# Out:
# '20251203-000018'

# %%
# File name.
"../data/" + now.strftime("%Y%m%d-%H%M%S") + ".csv"
# Out:
# '../data/20251203-000018.csv'

# %%
# Save data as CSV.
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html

df.to_csv("../data/" + dt.datetime.now().strftime("%Y%m%d-%H%M%S") + ".csv") # Save with timestamp in filename.

# %% [markdown]
# ## Plots

# %%
df # DataFrames are heterogeneous, meaning they can contain different data types in different columns.
# Out:
# Price                           Close                                      \
# Ticker                           AAPL        GOOG        MSFT        NVDA
# Datetime
# 2025-11-25 14:30:00+00:00  278.904999  327.320007  468.380005  171.074997
# 2025-11-25 15:30:00+00:00  277.829987  320.679993  472.149994  174.723801
# 2025-11-25 16:30:00+00:00  279.070099  321.404999  475.989990  175.535004
# 2025-11-25 17:30:00+00:00  278.760010  324.230011  476.744995  176.205002
# 2025-11-25 18:30:00+00:00  278.035004  323.007996  476.380005  174.774994
# 2025-11-25 19:30:00+00:00  277.565002  321.700104  477.088501  176.841705
# 2025-11-25 20:30:00+00:00  276.950012  323.649994  476.929993  177.800003
# 2025-11-26 14:30:00+00:00  277.809998  318.279999  483.239990  179.585007
# 2025-11-26 15:30:00+00:00  279.010101  319.635010  486.785492  180.910004
# 2025-11-26 16:30:00+00:00  279.079010  319.089996  486.790009  180.779999
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type((1, 2, 3))
# Out:
# tuple

# %%
type([1,2,3]) # a list is mutable while a tuple is not mutable
# Out:
# list

# %%
L = [1,2,3] # a list is mutable

L[1] = 4 # I can change the second element so I can mutate it

L
# Out:
# [1, 4, 3]

# %%
a = np.array([[1,2,3],[4,5,6]]) # a numerical array with 2 rows and 3 columns

a.dtype # data type of the elements in the array
# Out:
# dtype('int64')

# %%
a = np.array([[1.0,2,3],[4,5,6]]) # a numerical array with 2 rows and 3 columns. Numpy arrays are homogenous so all elements have the same data type.

a.dtype # data type of the elements in the array
# Out:
# dtype('float64')

# %%
# Just call plot() with no arguments and see what happens.
df.plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
# List the so-called columns of df.
df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close', 'GOOG'),
#             ( 'Close', 'MSFT'),
#             ( 'Close', 'NVDA'),
#             (  'High', 'AAPL'),
#             (  'High', 'GOOG'),
#             (  'High', 'MSFT'),
#             (  'High', 'NVDA'),
#             (   'Low', 'AAPL'),
#             (   'Low', 'GOOG'),
#             (   'Low', 'MSFT'),
#             (   'Low', 'NVDA'),
#             (  'Open', 'AAPL'),
#             (  'Open', 'GOOG'),
#             (  'Open', 'MSFT'),
#             (  'Open', 'NVDA'),
#             ('Volume', 'AAPL'),
#             ('Volume', 'GOOG'),
#             ('Volume', 'MSFT'),
#             ('Volume', 'NVDA')],
#            names=['Price', 'Ticker'])

# %%
# The closing price for Apple.
df[('Close', 'AAPL')]
# Out:
# Datetime
# 2025-11-25 14:30:00+00:00    278.904999
# 2025-11-25 15:30:00+00:00    277.829987
# 2025-11-25 16:30:00+00:00    279.070099
# 2025-11-25 17:30:00+00:00    278.760010
# 2025-11-25 18:30:00+00:00    278.035004
# 2025-11-25 19:30:00+00:00    277.565002
# 2025-11-25 20:30:00+00:00    276.950012
# 2025-11-26 14:30:00+00:00    277.809998
# 2025-11-26 15:30:00+00:00    279.010101
# 2025-11-26 16:30:00+00:00    279.079010
# 2025-11-26 17:30:00+00:00    278.549988
# 2025-11-26 18:30:00+00:00    278.260010
# 2025-11-26 19:30:00+00:00    278.079987
# 2025-11-26 20:30:00+00:00    277.470001
# 2025-11-28 14:30:00+00:00    276.260010
# 2025-11-28 15:30:00+00:00    276.250000
# 2025-11-28 16:30:00+00:00    277.049988
# 2025-12-01 14:30:00+00:00    278.142090
# 2025-12-01 15:30:00+00:00    277.920013
# 2025-12-01 16:30:00+00:00    279.770508
# 2025-12-01 17:30:00+00:00    280.588196
# 2025-12-01 18:30:00+00:00    280.890015
# 2025-12-01 19:30:00+00:00    281.910004
# ...

# %%
type(df[('Close', 'AAPL')]) # Series is a one-dimensional array with axis labels.
# Out:
# pandas.core.series.Series

# %%
df[('Close', 'AAPL')].plot(); # Plot the closing price for Apple.

# %%
# The closing price for all three.
df[[('Close', 'AAPL'), ('Close', 'MSFT'), ('Close', 'GOOG')]].plot();

# %%
# Try not to hard-code the stock names.
df['Close']
# Out:
# Ticker                           AAPL        GOOG        MSFT        NVDA
# Datetime
# 2025-11-25 14:30:00+00:00  278.904999  327.320007  468.380005  171.074997
# 2025-11-25 15:30:00+00:00  277.829987  320.679993  472.149994  174.723801
# 2025-11-25 16:30:00+00:00  279.070099  321.404999  475.989990  175.535004
# 2025-11-25 17:30:00+00:00  278.760010  324.230011  476.744995  176.205002
# 2025-11-25 18:30:00+00:00  278.035004  323.007996  476.380005  174.774994
# 2025-11-25 19:30:00+00:00  277.565002  321.700104  477.088501  176.841705
# 2025-11-25 20:30:00+00:00  276.950012  323.649994  476.929993  177.800003
# 2025-11-26 14:30:00+00:00  277.809998  318.279999  483.239990  179.585007
# 2025-11-26 15:30:00+00:00  279.010101  319.635010  486.785492  180.910004
# 2025-11-26 16:30:00+00:00  279.079010  319.089996  486.790009  180.779999
# 2025-11-26 17:30:00+00:00  278.549988  319.630005  486.831604  180.809998
# 2025-11-26 18:30:00+00:00  278.260010  319.149994  486.820007  180.550003
# ...

# %%
# Plot all closing prices.
df['Close'].plot(); # Plot the closing prices for all stocks.

# %% [markdown]
# ## Save Plot to File

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html

# %%
# Create new figure and axis
fig, ax = plt.subplots()

# Plot all closing prices.
df['Close'].plot(ax=ax)

# Save figure.
fig.savefig('../plots/test.png', dpi=300)

# %%
# Create new figure and axis
fig, ax = plt.subplots()

# Plot all closing prices.
df['Close'].plot(ax=ax)

# Current date and time.
now = dt.datetime.now()

# File name.
filename = "../plots/" + now.strftime("%Y%m%d-%H%M%S") + ".png" 

# Save figure.
fig.savefig(filename, dpi=300)

# %% [markdown]
# ## Index

# %%
# Row names

df.index
# Out:
# DatetimeIndex(['2025-11-25 14:30:00+00:00', '2025-11-25 15:30:00+00:00',
#                '2025-11-25 16:30:00+00:00', '2025-11-25 17:30:00+00:00',
#                '2025-11-25 18:30:00+00:00', '2025-11-25 19:30:00+00:00',
#                '2025-11-25 20:30:00+00:00', '2025-11-26 14:30:00+00:00',
#                '2025-11-26 15:30:00+00:00', '2025-11-26 16:30:00+00:00',
#                '2025-11-26 17:30:00+00:00', '2025-11-26 18:30:00+00:00',
#                '2025-11-26 19:30:00+00:00', '2025-11-26 20:30:00+00:00',
#                '2025-11-28 14:30:00+00:00', '2025-11-28 15:30:00+00:00',
#                '2025-11-28 16:30:00+00:00', '2025-12-01 14:30:00+00:00',
#                '2025-12-01 15:30:00+00:00', '2025-12-01 16:30:00+00:00',
#                '2025-12-01 17:30:00+00:00', '2025-12-01 18:30:00+00:00',
#                '2025-12-01 19:30:00+00:00', '2025-12-01 20:30:00+00:00',
#                '2025-12-02 14:30:00+00:00', '2025-12-02 15:30:00+00:00',
# ...

# %%
# Column names

df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close', 'GOOG'),
#             ( 'Close', 'MSFT'),
#             ( 'Close', 'NVDA'),
#             (  'High', 'AAPL'),
#             (  'High', 'GOOG'),
#             (  'High', 'MSFT'),
#             (  'High', 'NVDA'),
#             (   'Low', 'AAPL'),
#             (   'Low', 'GOOG'),
#             (   'Low', 'MSFT'),
#             (   'Low', 'NVDA'),
#             (  'Open', 'AAPL'),
#             (  'Open', 'GOOG'),
#             (  'Open', 'MSFT'),
#             (  'Open', 'NVDA'),
#             ('Volume', 'AAPL'),
#             ('Volume', 'GOOG'),
#             ('Volume', 'MSFT'),
#             ('Volume', 'NVDA')],
#            names=['Price', 'Ticker'])
