# %% [markdown]
# # yFinance
#
# https://github.com/ranaroussi/yfinance

# %%
# Yahoo Finance data.
import yfinance as yf

# %%
yf.download("AAPL", start="2020-01-01", end="2020-12-31")
# Out:
# /tmp/ipykernel_1724/1945424988.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf.download("AAPL", start="2020-01-01", end="2020-12-31")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.538513   72.598892   71.292304   71.545890  135480400
# 2020-01-03   71.833298   72.594063   71.608692   71.765674  146322800
# 2020-01-06   72.405678   72.444321   70.703012   70.954188  118387200
# 2020-01-07   72.065140   72.671333   71.845362   72.415330  108872000
# 2020-01-08   73.224396   73.526287   71.768071   71.768071  132079200
# ...                ...         ...         ...         ...        ...
# 2020-12-23  127.606911  129.039259  127.431512  128.776183   88223700
# 2020-12-24  128.591034  130.042889  127.743314  127.957683   54930100
# 2020-12-28  133.190186  133.823537  130.091599  130.559319  124486200
# 2020-12-29  131.416779  135.236409  130.900350  134.515365  121047300
# 2020-12-30  130.296234  132.508117  129.984420  132.108611   96452100
#
# [252 rows x 5 columns]

# %% [markdown]
# ## End
